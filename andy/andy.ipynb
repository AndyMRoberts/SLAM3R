# %%
import open3d as o3d

# Load the PLY file
pcd = o3d.io.read_point_cloud("/home/campus.ncl.ac.uk/c4071391/Projects/SLAM3R/results/andy_webcam_2/andy_webcam_2_online_recon.ply")
# pcd = o3d.io.read_point_cloud("results/Replica_demo_youtube_fields/data_youtube_field_recon.ply")
# pcd = o3d.io.read_point_cloud("results/Replica_demo_LFSD/D435i_RGB_recon.ply")
# pcd = o3d.io.read_point_cloud("results/Replica_demo_rosario/sequence04_zed_left_only_recon.ply")


# Visualize
o3d.visualization.draw_geometries([pcd])

# %%
import cv2
import matplotlib.pyplot as plt

video_capture = cv2.VideoCapture('/dev/video0')
ret, frame = video_capture.read()
video_capture.release()

if not ret:
    raise RuntimeError("failed to read from webcam")

# frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
plt.imshow(frame)
plt.axis("off")
plt.show()
