# %%
import open3d as o3d

# Load the PLY file
# pcd = o3d.io.read_point_cloud("results/Replica_demo/Replica_demo_room0_recon.ply")
pcd = o3d.io.read_point_cloud("results/Replica_demo_youtube_fields/data_youtube_field_recon.ply")

# Visualize
o3d.visualization.draw_geometries([pcd])
